# %%
from google.colab import drive

# %%
drive.mount("/F")
# Out:
# Mounted at /F

# %%
# !ls '/F/My Drive/Maratona/Redes Neurais Artificiais/'
# Out:
#  census.csv
# 'Classificação Binária XOR.ipynb'
# 'Classificação Multiclasse Iris II.ipynb'
# 'Classificação MultiClasse Iris.ipynb'
#  house_prices.csv
# 'Percepton de 1 Camada II.ipynb'
# 'Percepton de uma Camada.ipynb'
# 'RNA Regressão Estimators Casas.ipynb'
# 'RNA Regressão Estimators Census.ipynb'

# %%
import pandas as pd

# %%
base = pd.read_csv("/F/My Drive/Maratona/Redes Neurais Artificiais/census.csv")

# %%
base.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
base.income.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def converte_classe(rotulo):
  if rotulo == ' >50k':
    return 1
  else:
    return 0

# %%
base.income = base.income.apply(converte_classe)

# %%
base.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country income
# 0   39          State-gov         77516  ...            40   United-States      0
# 1   50   Self-emp-not-inc         83311  ...            13   United-States      0
# 2   38            Private        215646  ...            40   United-States      0
# 3   53            Private        234721  ...            40   United-States      0
# 4   28            Private        338409  ...            40            Cuba      0
#
# [5 rows x 15 columns]

# %%
X = base.drop('income', axis = 1)
y = base.income

# %%
X.head()
# Out:
#    age          workclass  ...  hour-per-week  native-country
# 0   39          State-gov  ...             40   United-States
# 1   50   Self-emp-not-inc  ...             13   United-States
# 2   38            Private  ...             40   United-States
# 3   53            Private  ...             40   United-States
# 4   28            Private  ...             40            Cuba
#
# [5 rows x 14 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_treinamento.shape
# Out:
# (22792, 14)

# %%
X_teste.shape
# Out:
# (9769, 14)

# %%
base.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
base.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
workclass = tf.feature_column.categorical_column_with_hash_bucket(key = 'workclass', hash_bucket_size = 100)
education = tf.feature_column.categorical_column_with_hash_bucket(key = 'education', hash_bucket_size = 100)
marital_status = tf.feature_column.categorical_column_with_hash_bucket(key = 'marital-status', hash_bucket_size = 100)
occupation = tf.feature_column.categorical_column_with_hash_bucket(key = 'occupation', hash_bucket_size = 100)
relationship = tf.feature_column.categorical_column_with_hash_bucket(key = 'relationship', hash_bucket_size = 100)
race = tf.feature_column.categorical_column_with_hash_bucket(key = 'race', hash_bucket_size = 100)
country = tf.feature_column.categorical_column_with_hash_bucket(key = 'native-country', hash_bucket_size = 100)

# %%
base.sex.unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
sex = tf.feature_column.categorical_column_with_vocabulary_list(key = 'sex', vocabulary_list=[' Male', ' Female'])

# %%
base.age.mean()
# Out:
# 38.58164675532078

# %%
base.age.std()
# Out:
# 13.640432553581146

# %%
def padroniza_age(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(38.58)), tf.constant(13.64))

def padroniza_finalweight(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(189778.36)), tf.constant(105549.977))

def padroniza_education(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(10.08)), tf.constant(2.57))

def padroniza_capitalgain(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(1077.64)), tf.constant(7385.29))

def padroniza_capitalloos(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(87.30)), tf.constant(402.96))

def padroniza_hour(valor):
    return tf.divide(tf.subtract(tf.cast(valor, tf.float32), tf.constant(40.43)), tf.constant(12.34))

# %%
age = tf.feature_column.numeric_column(key = 'age', normalizer_fn = padroniza_age)
final_weight = tf.feature_column.numeric_column(key = 'final-weight', normalizer_fn = padroniza_finalweight)
education_num = tf.feature_column.numeric_column(key = 'education-num', normalizer_fn = padroniza_education)
capital_gain = tf.feature_column.numeric_column(key = 'capital-gain', normalizer_fn = padroniza_capitalgain)
capital_loos = tf.feature_column.numeric_column(key = 'capital-loos', normalizer_fn = padroniza_capitalloos)
hour = tf.feature_column.numeric_column(key = 'hour-per-week', normalizer_fn = padroniza_hour)

# %%
len(base.workclass.unique())
# Out:
# 9

# %%
embedded_workclass = tf.feature_column.embedding_column(workclass, dimension = 9)
embedded_education = tf.feature_column.embedding_column(education, dimension = len(base.education.unique()))
embedded_marital = tf.feature_column.embedding_column(marital_status, dimension = len(base['marital-status'].unique()))
embedded_occupation = tf.feature_column.embedding_column(occupation, dimension = len(base.occupation.unique()))
embedded_relationship = tf.feature_column.embedding_column(relationship, dimension = len(base.relationship.unique()))
embedded_race = tf.feature_column.embedding_column(race, dimension = len(base.race.unique()))
embedded_sex = tf.feature_column.embedding_column(sex, dimension = len(base.sex.unique()))
embedded_country = tf.feature_column.embedding_column(country, dimension = len(base['native-country'].unique()))

# %%
colunas_rna = [age, embedded_workclass, final_weight, embedded_education, education_num,
               embedded_marital, embedded_occupation, embedded_relationship, 
               embedded_race, embedded_sex,
               capital_gain, capital_loos, hour, embedded_country]

# %%
def make_input_fn(X, y = None, num_epochs = None, shuffle = True, batch_size=32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(X), y))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    return input_function

# %%
funcao_treinamento = make_input_fn(X_treinamento, y_treinamento)

# %%
config = tf.estimator.RunConfig(tf_random_seed = 42)
classificador = tf.estimator.DNNClassifier(hidden_units = [8, 8], feature_columns = colunas_rna, n_classes = 2, config = config)
classificador.train(input_fn = funcao_treinamento, steps = 10000)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmplna1gmru
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmplna1gmru', '_tf_random_seed': 42, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmplna1gmru/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.70122254, step = 0
# INFO:tensorflow:global_step/sec: 217.463
# INFO:tensorflow:loss = 0.6170857, step = 100 (0.465 sec)
# INFO:tensorflow:global_step/sec: 588.026
# INFO:tensorflow:loss = 0.5723281, step = 200 (0.167 sec)
# INFO:tensorflow:global_step/sec: 637.536
# INFO:tensorflow:loss = 0.54910463, step = 300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 596.707
# INFO:tensorflow:loss = 0.4954062, step = 400 (0.170 sec)
# INFO:tensorflow:global_step/sec: 479.231
# INFO:tensorflow:loss = 0.4765366, step = 500 (0.206 sec)
# INFO:tensorflow:global_step/sec: 561.911
# INFO:tensorflow:loss = 0.4366604, step = 600 (0.178 sec)
# INFO:tensorflow:global_step/sec: 480.78
# INFO:tensorflow:loss = 0.39198926, step = 700 (0.208 sec)
# INFO:tensorflow:global_step/sec: 428.66
# INFO:tensorflow:loss = 0.38007405, step = 800 (0.235 sec)
# INFO:tensorflow:global_step/sec: 494.71
# INFO:tensorflow:loss = 0.34749395, step = 900 (0.200 sec)
# INFO:tensorflow:global_step/sec: 505.413
# INFO:tensorflow:loss = 0.32518005, step = 1000 (0.198 sec)
# INFO:tensorflow:global_step/sec: 462.783
# INFO:tensorflow:loss = 0.29542527, step = 1100 (0.216 sec)
# INFO:tensorflow:global_step/sec: 549.996
# INFO:tensorflow:loss = 0.27795833, step = 1200 (0.186 sec)
# INFO:tensorflow:global_step/sec: 493.75
# INFO:tensorflow:loss = 0.24727271, step = 1300 (0.199 sec)
# INFO:tensorflow:global_step/sec: 543.599
# INFO:tensorflow:loss = 0.24071051, step = 1400 (0.185 sec)
# INFO:tensorflow:global_step/sec: 517.734
# INFO:tensorflow:loss = 0.23047386, step = 1500 (0.192 sec)
# INFO:tensorflow:global_step/sec: 471.778
# INFO:tensorflow:loss = 0.20152068, step = 1600 (0.212 sec)
# INFO:tensorflow:global_step/sec: 510.25
# INFO:tensorflow:loss = 0.1897936, step = 1700 (0.199 sec)
# INFO:tensorflow:global_step/sec: 488.502
# INFO:tensorflow:loss = 0.18273354, step = 1800 (0.205 sec)
# INFO:tensorflow:global_step/sec: 481.117
# INFO:tensorflow:loss = 0.13867, step = 1900 (0.205 sec)
# INFO:tensorflow:global_step/sec: 483.709
# INFO:tensorflow:loss = 0.16794287, step = 2000 (0.210 sec)
# INFO:tensorflow:global_step/sec: 518.696
# INFO:tensorflow:loss = 0.14116299, step = 2100 (0.190 sec)
# INFO:tensorflow:global_step/sec: 486.311
# INFO:tensorflow:loss = 0.10280458, step = 2200 (0.211 sec)
# INFO:tensorflow:global_step/sec:
 (0.192 sec)
# INFO:tensorflow:global_step/sec: 492.874
# INFO:tensorflow:loss = 0.035033077, step = 6800 (0.203 sec)
# INFO:tensorflow:global_step/sec: 559.56
# INFO:tensorflow:loss = 0.02129278, step = 6900 (0.182 sec)
# INFO:tensorflow:global_step/sec: 465.772
# INFO:tensorflow:loss = 0.017823534, step = 7000 (0.213 sec)
# INFO:tensorflow:global_step/sec: 478.722
# INFO:tensorflow:loss = 0.021420918, step = 7100 (0.208 sec)
# INFO:tensorflow:global_step/sec: 489.19
# INFO:tensorflow:loss = 0.03854753, step = 7200 (0.205 sec)
# INFO:tensorflow:global_step/sec: 417.404
# INFO:tensorflow:loss = 0.020470122, step = 7300 (0.239 sec)
# INFO:tensorflow:global_step/sec: 447.956
# INFO:tensorflow:loss = 0.025186889, step = 7400 (0.228 sec)
# INFO:tensorflow:global_step/sec: 443.53
# INFO:tensorflow:loss = 0.027733622, step = 7500 (0.222 sec)
# INFO:tensorflow:global_step/sec: 547.474
# INFO:tensorflow:loss = 0.026016619, step = 7600 (0.181 sec)
# INFO:tensorflow:global_step/sec: 562.821
# INFO:tensorflow:loss = 0.026145134, step = 7700 (0.179 sec)
# INFO:tensorflow:global_step/sec: 494.644
# INFO:tensorflow:loss = 0.014912905, step = 7800 (0.204 sec)
# INFO:tensorflow:global_step/sec: 498.751
# INFO:tensorflow:loss = 0.014040001, step = 7900 (0.197 sec)
# INFO:tensorflow:global_step/sec: 500.89
# INFO:tensorflow:loss = 0.023546431, step = 8000 (0.200 sec)
# INFO:tensorflow:global_step/sec: 528.718
# INFO:tensorflow:loss = 0.024810735, step = 8100 (0.189 sec)
# INFO:tensorflow:global_step/sec: 498.588
# INFO:tensorflow:loss = 0.01283315, step = 8200 (0.201 sec)
# INFO:tensorflow:global_step/sec: 475.483
# INFO:tensorflow:loss = 0.011991307, step = 8300 (0.210 sec)
# INFO:tensorflow:global_step/sec: 514.745
# INFO:tensorflow:loss = 0.01826537, step = 8400 (0.197 sec)
# INFO:tensorflow:global_step/sec: 519.37
# INFO:tensorflow:loss = 0.015661884, step = 8500 (0.194 sec)
# INFO:tensorflow:global_step/sec: 429.735
# INFO:tensorflow:loss = 0.022419158, step = 8600 (0.233 sec)
# INFO:tensorflow:global_step/sec: 474.877
# INFO:tensorflow:loss = 0.013187494, step = 8700 (0.206 sec)
# INFO:tensorflow:global_step/sec: 508.42
# INFO:tensorflow:loss = 0.014298299, step = 8800 (0.196 sec)
# INFO:tensorflow:global_step/sec: 527.483
# INFO:tensorflow:loss = 0.012358435, step = 8900 (0.192 sec)
# INFO:tensorflow:global_step/sec: 552.145
# INFO:tensorflow:loss = 0.01070709, step = 9000 (0.179 sec)
# INFO:tensorflow:global_step/sec: 498.549
# INFO:tensorflow:loss = 0.016361935, step = 9100 (0.206 sec)
# INFO:tensorflow:global_step/sec: 478.249
# INFO:tensorflow:loss = 0.014609039, step = 9200 (0.203 sec)
# INFO:tensorflow:global_step/sec: 401.65
# INFO:tensorflow:loss = 0.016077034, step = 9300 (0.250 sec)
# INFO:tensorflow:global_step/sec: 460.829
# INFO:tensorflow:loss = 0.015272392, step = 9400 (0.216 sec)
# INFO:tensorflow:global_step/sec: 529.987
# INFO:tensorflow:loss = 0.01226222, step = 9500 (0.189 sec)
# INFO:tensorflow:global_step/sec: 726.298
# INFO:tensorflow:loss = 0.017937938, step = 9600 (0.140 sec)
# INFO:tensorflow:global_step/sec: 451.631
# INFO:tensorflow:loss = 0.009918682, step = 9700 (0.220 sec)
# INFO:tensorflow:global_step/sec: 505.813
# INFO:tensorflow:loss = 0.008842554, step = 9800 (0.199 sec)
# INFO:tensorflow:global_step/sec: 501.654
# INFO:tensorflow:loss = 0.0070314, step = 9900 (0.201 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmplna1gmru/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Loss for final step: 0.014072824.

# %%
funcao_teste = make_input_fn(X_teste, y_teste, num_epochs = 1, shuffle = False)

# %%
classificador.evaluate(input_fn = funcao_teste, steps = 10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-26T11:44:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmplna1gmru/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.51165s
# INFO:tensorflow:Finished evaluation at 2021-01-26-11:44:58
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 1.0, accuracy_baseline = 1.0, auc = 0.0, auc_precision_recall = 0.0, average_loss = 0.012314527, global_step = 10000, label/mean = 0.0, loss = 0.012302421, precision = 0.0, prediction/mean = 0.012044854, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /tmp/tmplna1gmru/model.ckpt-10000
# {'accuracy': 1.0,
#  'accuracy_baseline': 1.0,
#  'auc': 0.0,
#  'auc_precision_recall': 0.0,
#  'average_loss': 0.012314527,
#  'global_step': 10000,
#  'label/mean': 0.0,
#  'loss': 0.012302421,
#  'precision': 0.0,
#  'prediction/mean': 0.012044854,
#  'recall': 0.0}
