# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount("/F")
# Out:
# Mounted at /F

# %%
# !ls '/F/My Drive/Maratona/Regressão Linear/'
# Out:
#  house_prices.csv		'Regressão Linear II.ipynb'
# 'Regressão Linear Casas.ipynb'	'Regressão Linear.ipynb'
# 'Regressão Linear III.ipynb'

# %%
base = pd.read_csv('/F/My Drive/Maratona/Regressão Linear/house_prices.csv')

# %%
base.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
base.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
base.shape
# Out:
# (21613, 21)

# %%
X = base.iloc[:, 5].values
X = X.reshape(-1,1)

# %%
X.shape
# Out:
# (21613, 1)

# %%
X
# Out:
# array([[1180],
#        [2570],
#        [ 770],
#        ...,
#        [1020],
#        [1600],
#        [1020]])

# %%
y = base.iloc[:, 2:3].values

# %%
y
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])

# %%
from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)
scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
X
# Out:
# array([[-0.97983502],
#        [ 0.53363434],
#        [-1.42625404],
#        ...,
#        [-1.15404732],
#        [-0.52252773],
#        [-1.15404732]])

# %%
y
# Out:
# array([[-0.86671733],
#        [-0.00568792],
#        [-0.98084935],
#        ...,
#        [-0.37586519],
#        [-0.38158814],
#        [-0.58588173]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X, y)

# %%
import numpy as np
np.random.seed(1)
np.random.rand(2)
# Out:
# array([0.417022  , 0.72032449])

# %%
import tensorflow as tf

# %% [markdown]
# y = b0 + b1*x

# %%
b0 = tf.Variable(0.41)
b1 = tf.Variable(0.72)

# %%
def linear_regression(x):
    return b0 + b1 * x

# %%
def error(y_pred, y_true):
    return tf.reduce_mean(tf.pow(y_pred - y_true, 2))

# %%
optimizer = tf.optimizers.SGD(learning_rate = 0.001)

# %%
batch_size = 32

# %%
for i in range(1000):
    indices = np.random.randint(len(X), size = batch_size)
    # Agrupa a computação dentro de um GradientTape
    with tf.GradientTape() as g:
        pred = linear_regression(X[indices])
        loss = error(pred, y[indices])

    # Computa os gradientes
    gradients = g.gradient(loss, [b1, b0])

    # Atualiza b1 e b0 seguindo os gradientes
    optimizer.apply_gradients(zip(gradients, [b1, b0]))

# %%
previsoes = b0 + b1 * X

# %%
previsoes = previsoes.numpy()

# %%
plt.plot(X, y, 'o')
plt.plot(X, previsoes, color = 'red')

# %%
y1 = scaler_y.inverse_transform(y)
previsoes1 = scaler_y.inverse_transform(previsoes)

# %%
y1
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])

# %%
previsoes1
# Out:
# array([[307221.38],
#        [699357.7 ],
#        [191555.27],
#        ...,
#        [262083.39],
#        [425708.6 ],
#        [262083.39]], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y1, previsoes1)
mae
# Out:
# 176858.2583073555
